# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import autogluon as ag
from autogluon.tabular import TabularPredictor

# %%
# df = pd.read_csv(r'C:\Users\himgoyal.ext\Desktop\MY DRIVE\AutoML\Experiment\Data\hotel_bookings.csv')
df = pd.read_csv(r'C:\Users\himgoyal.ext\Desktop\MY DRIVE\AutoML\Experiment\New_Data\hotel_bookings_New.csv')

# %%
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# %%
train_data.describe()
# Out:
#           lead_time  arrival_date_year  arrival_date_week_number  \
# count  95512.000000       95512.000000              95512.000000
# mean     104.002911        2016.156190                 27.173203
# std      106.778585           0.707095                 13.608064
# min        0.000000        2015.000000                  1.000000
# 25%       18.000000        2016.000000                 16.000000
# 50%       69.000000        2016.000000                 28.000000
# 75%      160.000000        2017.000000                 38.000000
# max      737.000000        2017.000000                 53.000000
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count               95512.000000             95512.000000
# mean                   15.808841                 0.929087
# std                     8.790791                 0.997902
# min                     1.000000                 0.000000
# 25%                     8.000000                 0.000000
# ...

# %%
# %%time
predictor = TabularPredictor(label='is_canceled').fit(train_data=train_data)
predictions = predictor.predict(test_data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20220723_184636\"
# ...
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20220723_184636\"
# AutoGluon Version:  0.5.1
# Python Version:     3.9.12
# Operating System:   Windows
# Train Data Rows:    95512
# Train Data Columns: 30
# Label Column: is_canceled
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [True, False]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# ...

# %%
predictor.leaderboard(test_data)
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       NeuralNetFastAI    0.999414     0.9996        0.353079       0.061014  107.945413                 0.353079                0.061014         107.945413            1       True         10
# 1   WeightedEnsemble_L2    0.999414     0.9996        0.387086       0.064014  108.787601                 0.034007                0.003000           0.842189            2       True         14
# 2              LightGBM    0.998995     0.9992        0.161036       0.032007    2.449549                 0.161036                0.032007           2.449549            1       True          4
# 3         LightGBMLarge    0.998534     0.9992        0.185041       0.026004    3.583804                 0.185041                0.026004           3.583804            1       True         13
# ...

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                   model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       NeuralNetFastAI     0.9996       0.061014  107.945413                0.061014         107.945413            1       True         10
# 1   WeightedEnsemble_L2     0.9996       0.064014  108.787601                0.003000           0.842189            2       True         14
# 2               XGBoost     0.9992       0.022895    2.807225                0.022895           2.807225            1       True         11
# 3         LightGBMLarge     0.9992       0.026004    3.583804                0.026004           3.583804            1       True         13
# 4              LightGBM     0.9992       0.032007    2.449549                0.032007           2.449549            1       True          4
# ...
