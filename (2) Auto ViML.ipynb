# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

from autoviml.Auto_ViML import Auto_ViML

# %%
# df = pd.read_csv(r'C:\Users\himgoyal.ext\Desktop\MY DRIVE\AutoML\Experiment\Data\hotel_bookings.csv')
df = pd.read_csv(r'C:\Users\himgoyal.ext\Desktop\MY DRIVE\AutoML\Experiment\Data\WA_Fn-UseC_-Telco-Customer-Churn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
# X = df.drop(['is_canceled'], axis=1)
# y = df['is_canceled']

# %%
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
# target = 'is_canceled'
target = 'Churn'

# %%
# %%time
model, features, trainm, testm = Auto_ViML(train_df, target, test_df, sample_submission='',
                                    scoring_parameter='',
                                    hyper_param='RS',feature_reduction=True,
                                     Boosting_Flag=True,Binning_Flag=False,
                                    Add_Poly=0, Stacking_Flag=True, 
                                    Imbalanced_Flag=True, 
                                    verbose=1)
# Out:
# ##############  D A T A   S E T  A N A L Y S I S  #######################
# Training Set Shape = (5634, 21)
#     Training Set Memory Usage = 0.95 MB
# Test Set Shape = (1409, 21)
#     Test Set Memory Usage = 0.24 MB
# Single_Label Target: ['Churn']
#
# ################ Binary_Classification VISUALIZATION Started #####################
# Random shuffling the data set before training
#     Using RandomizedSearchCV for Hyper Parameter Tuning. This is 3X faster than GridSearchCV...
#        Class  -> Counts -> Percent
#           No:    4138  ->   73.4%
#          Yes:    1496  ->   26.6%
# String or Multi Class target: Churn transformed as follows: {'No': 0, 'Yes': 1}
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# ...

# %%
features # 15 feature
# Out:
# ['Contract',
#  'OnlineSecurity',
#  'TechSupport',
#  'tenure',
#  'InternetService',
#  'MonthlyCharges',
#  'TotalCharges',
#  'OnlineBackup',
#  'PaymentMethod',
#  'PaperlessBilling',
#  'StreamingMovies',
#  'Dependents',
#  'StreamingTV',
#  'Naive Bayes_0',
#  'Naive Bayes_1']

# %%
testm
# Out:
#       customerID  Contract  OnlineSecurity  TechSupport  tenure  \
# 185   1024-GUALD      0.00            0.00         0.00    0.01
# 2715  0484-JPBRU      0.00            0.50         0.50    0.57
# 3825  3620-EHIMZ      1.00            0.50         0.50    0.72
# 1807  6910-HADCM      0.00            0.00         0.00    0.01
# 132   8587-XYZSF      1.00            0.00         1.00    0.93
# ...          ...       ...             ...          ...     ...
# 6366  2845-KDHVX      1.00            0.00         1.00    0.89
# 315   5027-YOCXN      0.50            1.00         1.00    0.71
# 2439  8884-MRNSU      0.50            0.50         0.50    0.24
# 5002  0567-XRHCU      1.00            1.00         0.00    0.96
# 1161  5868-CZJDR      0.00            0.00         0.00    0.01
#
#       InternetService  MonthlyCharges  TotalCharges  OnlineBackup  \
# 185              0.00            0.07          0.31          0.00
# ...

# %%
model
# Out:
# SelfPacedEnsembleClassifier(base_estimator=RandomForestClassifier(random_state=99),
#                             n_jobs=-1,
#                             random_state=RandomState(MT19937) at 0x1C10D155040)

# %%
print(confusion_matrix(test_df[target].values,testm['Churn_Stacked_Naive Bayes_predictions'].values))
# Out:
# [[767 269]
#  [ 74 299]]
